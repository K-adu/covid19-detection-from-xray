# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img("Documents/chest_xray/train/PNEUMONIA/person1_bacteria_2.jpeg")
plt.imshow(img)

# %%
cv2.imread("Documents/chest_xray/train/PNEUMONIA/person1_bacteria_2.jpeg")
# Out:
# array([[[ 15,  15,  15],
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         ...,
#         [ 42,  42,  42],
#         [ 43,  43,  43],
#         [ 44,  44,  44]],
#
#        [[ 13,  13,  13],
#         [ 12,  12,  12],
#         [ 12,  12,  12],
#         ...,
#         [ 44,  44,  44],
#         [ 45,  45,  45],
#         [ 45,  45,  45]],
#
#        [[ 11,  11,  11],
#         [ 11,  11,  11],
#         [ 10,  10,  10],
#         ...,
#         [ 46,  46,  46],
#         [ 45,  45,  45],
#         [ 45,  45,  45]],
#
#        ...,
#
#        [[ 29,  29,  29],
#         [ 32,  32,  32],
#         [ 17,  17,  17],
#         ...,
#         [ 10,  10,  10],
#         [ 22,  22,  22],
#         [ 21,  21,  21]],
#
#        [[254, 254, 254],
#         [222, 222, 222],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [231, 231, 231],
#         [255, 255, 255]],
#
#        [[  0,   0,   0],
#         [ 21,  21,  21],
#         [  0,   0,   0],
# ...

# %%
train = ImageDataGenerator(rescale = 1/255)
test = ImageDataGenerator(rescale= 1/255)

# %%
train_dataset= train.flow_from_directory('Documents/chest_xray/train/',target_size=(200,200),batch_size=100,class_mode='binary')
test_dataset= test.flow_from_directory('Documents/chest_xray/test/',target_size=(200,200),batch_size=100,class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}
